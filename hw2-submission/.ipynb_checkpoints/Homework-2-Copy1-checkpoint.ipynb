# %% [markdown]
# (In order to load the stylesheet of this notebook, execute the last code cell in this notebook)

# %% [markdown]
# # Yelp Reviews and Clustering

# %% [markdown]
# In this assignment, we will be working with the [Yelp dataset](http://cs-people.bu.edu/kzhao/teaching/yelp_dataset_challenge_academic_dataset.tar). You can find the format of the dataset [here](https://www.yelp.com/dataset_challenge).

# %% [markdown]
# First, we will look at Review Objects and perform some [sentiment analysis](http://sentiment.christopherpotts.net/) on the review text.
#
# You will need to preprocess the text using a stemming algorithm. The Porter stemming algorithm is a well-known one. Then, use a lexicon to assign a score to a review based on the positive/negative words you find in the text. You can find various lexicons [here](http://sentiment.christopherpotts.net/lexicons.html).
#
# After you have assigned scores to the reviews based on the text analysis, compare your scores with the stars associated with the reviews. **(20 pts)**

# %%
import unicodedata
import json
import pandas as pd
from nltk.corpus import stopwords
import nltk
from nltk.stem import *
import copy

#Parse json file and create list of stars and text for each review
def parsedata(filename):

    data = open(filename)
    stars = []
    text = []
    stopWords = stopwords.words("english")
    review = []
    for line in data:
        reviews = json.loads(line)
        stars.append(reviews['stars'])
        text.append(reviews['text'])   

    data.close()


    dicts = []

    for i in range(0,len(stars)):
        review.append([stars[i], text[i]])


    stars = None
    text = None

    return review
abcd = parsedata('yelp_academic_dataset_review.json')

# %%
#Vader Lexicon: Use the Vader Lexicon, to assign a score for each text review
edcba = copy.deepcopy(abcd)
def scoretext(lsts):
    lexdix = {}
    score= []
    stars = []
    dicts = []
    with open('vader_lexicon.txt') as lexicon:
        for line in lexicon:
            entry = line.split()
            if entry:
                lexdix.update({entry[0]: entry[1]})       
        for j in lsts:
            k = float(0)
            stars.append(j[0])
            tmpscore = float(0)
            j[1] = j[1].split()
            for i in j[1]:
                if i in lexdix:
                    k = k+1
                    tmpscore = tmpscore + float(lexdix.get(i))
            score.append(k*tmpscore)
            
        for i in range(0,len(stars)):
            review = {'stars' : stars[i], 'score' : score[i]}
            dicts.append(review)

        dataframe = pd.DataFrame(dicts, columns = ['stars', 'score'])
        dicts = None
#return  a dataframe of stars with the corresponding score
        return (dataframe)

df = scoretext(edcba)
print(df)
# Out:
#          stars   score
# 0            4    19.8
# 1            5     5.0
# 2            5    33.6
# 3            5   125.3
# 4            3    72.8
# 5            1    15.9
# 6            4    11.7
# 7            5     7.8
# 8            5   243.6
# 9            3    61.6
# 10           1    95.4
# 11           1     1.5
# 12           4    41.3
# 13           4     6.4
# 14           5    52.2
# 15           2    13.5
# 16           4     7.6
# 17           1    -2.8
# 18           1     0.0
# 19           5    64.8
# 20           5     4.2
# 21           5   219.0
# 22           4     9.6
# 23           5    74.0
# 24           5    62.0
# 25           5    31.2
# 26           4     1.5
# 27           5  1692.6
# 28           4    63.0
# 29           5    32.0
# ...        ...     ...
# 2225183      5    83.4
# 2225184      2   -15.0
# 2225185      5    69.6
# 2225186      5    30.0
# 2225187      5     7.8
# 2225188      5    54.0
# 2225189      5    26.4
# 2225190      1    -1.2
# 2225191      4    28.2
# 2225192      1   -11.2
# 2225193      5   166.5
# 2225194      5    20.1
# 2225195      5    -3.6
# 2225196      5     9.2
# 2225197      5    11.0
# 2225198      5    19.5
# 2225199      1   217.5
# 2225200      5   294.0
# 2225201      5    53.4
# 2225202      5    98.0
# 2225203      1    72.8
# 2225204      1     1.2
# 2225205      5    76.0
# 2225206      3    11.6
# 2225207      1    10.4
# 2225208      1  -126.0
# 2225209      4     0.4
# 2225210      5     8.8
# 2225211      1  -109.2
# 2225212      5   148.5
#
# [2225213 rows x 2 columns]

# %% [markdown]
# Visualization and short (detailed) analysis. **(10 pts)**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#plot the score to stars scatter plots
plotdf = df.copy()  
one = 0
o = 0
two = 0
tw = 0
three = 0
th = 0
four = 0
fo = 0
five = 0
fi =0
for index, row in plotdf.iterrows():
    if row['stars'] == 1:
        one = one + row['score']
        o = o+1
    if row['stars'] == 2:
        two = two + row['score']
        tw = tw +1
    if row['stars'] == 3:
        three = three + row['score']
        th = th +1
    if row['stars'] == 4:
        four = four + row['score']
        fo = fo +1
    if row['stars'] == 5:
        five = five + row['score']
        fi = fi+1
one = one/o
two = two/tw
three = three/th
four = four/fo
five = five/fi
#plot the average score per star to number of stars
dframe = pd.DataFrame([[1,one],[2,two],[3,three],[4,four],[5,five]], columns = ['stars', 'score'])
print (dframe)
# Out:
#    stars       score
# 0      1   18.263735
# 1      2   64.887073
# 2      3   91.862492
# 3      4  107.679742
# 4      5   93.478707

# %%
df.plot('stars', 'score', 'scatter')
dframe.plot('stars', 'score', 'line')
#As we see in the first plot, using the Vader Lexicon is not doing a great job predicting efficiently the stars given by the reviewer.
#Vader assigns a score to each word in the review if in the lexicon. Then we add the scores for each word in the review and multiply by the number of words 
#of the review in the lexicon to yield a raw score. The reason why reviews with low stars may get a high score, could be the fact that they have many words 
#in the lexicon, and their raw score ends up being positive, and the when multiplied by the number of words yields a large score
#The reason why many reviews with a good star rating end up with a low score could be the fact that there are not many words of the review
#in the lexicon thus yielding a low raw score.
#However as we see in the second plot, which is a plot of average score per review with the same number of stars to the number of stars, 
#the relationship is increasing, meaning that our method does a good job for most of the reviews, as the average score for reviews of the same star is
#increasing as the stars increase. it cannot however distinguish very well the difference between 4 and 5 stars.

# %% [markdown]
# -----------------

# %% [markdown]
# Now, let's look at Business Objects. Try to find culinary districts in Las Vegas. These are characterized by closeness and similarity of restaurants. Use the "longitude" and "latitude" to cluster closeness. Use "categories" and "attributes" to cluster for similarity.
#
# Find clusters using the 3 different techniques we discussed in class: k-means++, hierarchical, and GMM. Explain your data representation and how you determined certain parameters (for example, the number of clusters in k-means++). **(30 pts)**
#
# Things you may want to consider:
# 1. The spatial coordinates and restaurant categories/attributes have different units of scale. Your results could be arbitrarily skewed if you don't incorporate some scaling.
# 2. Some restaurant types are inherently more common than others. For example, there are probably lots of "pizza" restaurants. You may want to normalize your vectors so that you don't end up with only clusters of "pizza" restaurants.

# %%
#
def getBusiness(filename):
    
    yelp_dataset = open(filename)
    lv_restaurants = []
    
    for line in yelp_dataset:
        current_business = json.loads(line)
        if ("Restaurants" in current_business['categories']) and (current_business['city'] == "Las Vegas") and ('Price Range' in current_business['attributes'].keys()):
            restaurant_info = {'latitude' : current_business['latitude'], 'longitude' : current_business['longitude'], 'categories' : current_business['categories'], 'price range' : (current_business['attributes']['Price Range'])}
            lv_restaurants.append(restaurant_info)
    
    
        
    yelp_dataset.close()
    return lv_restaurants

# %%
#
def getTypes(filename):
    
    yelp_dataset = open(filename)
    restaurant_types = []
    
    for line in yelp_dataset:
        current_business = json.loads(line)
        if "Restaurants" in current_business['categories'] and current_business['city'] == "Las Vegas":
            for tag in current_business['categories']:
                if tag != "Restaurants" and not tag in restaurant_types:
                    restaurant_types.append(str(tag))
    
    yelp_dataset.close()
    return restaurant_types

# %%
#
def vectorizeRestaurants(restaurants, types):
    
    for curr_restaurant in restaurants:
        for _type in types:
            if _type in curr_restaurant['categories']:
                curr_restaurant[_type] = 1
            else:
                curr_restaurant[_type] = 0
        del curr_restaurant['categories']
        
    return restaurants

# %% [markdown]
# Visualize your clusters using each technique. Label your clusters. **(10 pts)**

# %%
#KMEANS++
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
import sklearn.metrics as metrics
from sklearn.cluster import KMeans
import scipy.sparse.linalg as linalg
import scipy.cluster.hierarchy as hr
from sklearn.feature_extraction import DictVectorizer
from scipy.cluster.hierarchy import dendrogram, linkage
import sklearn.cluster as cluster
from scipy.cluster.hierarchy import cophenet
from sklearn.decomposition import TruncatedSVD
from scipy.spatial.distance import pdist
from scipy.spatial.distance import pdist, squareform
from sklearn.preprocessing import StandardScaler
from sklearn import mixture
from __future__ import print_function
from nltk.stem import *
from nltk.corpus import stopwords
import json
import sys
from collections import Counter

#import matplotlib as mpl
# %matplotlib inline

restaurants_lv = getBusiness('/Users/johnsakk/Desktop/yelp_dataset_challenge_academic_dataset/yelp_academic_dataset_business.json')
types_lv = getTypes('/Users/johnsakk/Desktop/yelp_dataset_challenge_academic_dataset/yelp_academic_dataset_business.json')
#print (restaurants_lv)
data = vectorizeRestaurants(restaurants_lv, types_lv)
#print(data)
vectors = np.asarray(data)

vec = DictVectorizer()
kmeans = KMeans(init = 'k-means++', n_clusters = 8)
gmm = mixture.GMM(n_components = 8, covariance_type='diag')



vector_arr = vec.fit_transform(vectors).toarray()



#print(len(vector_arr[0]))
#print(vector_arr[0])
kmeans.fit(vector_arr)
 
centroids = kmeans.cluster_centers_
labels= kmeans.labels_ # list of restaurant belonging cluster
#print (labels[:30])

restindex = -1
cluster0 = []
cluster1 = []
cluster2 = []
cluster3 = []
cluster4 = []
cluster5 = []
cluster6 = []
cluster7 = []
for i in labels:
    restindex = restindex + 1
    if i == 0:
        cluster0.append(restindex)
    if i == 1:
        cluster1.append(restindex)
    if i == 2:
        cluster2.append(restindex)
    if i == 3:
        cluster3.append(restindex)
    if i == 4:
        cluster4.append(restindex)
    if i == 5:
        cluster5.append(restindex)
    if i == 6:
        cluster6.append(restindex)
    if i == 7:
        cluster7.append(restindex)

        
def labelit(a, b):
    clusterlabel = []
    for j in a:
        for key in b[j]:
            if (b[j])[key] == 1 and key != 'price range'and key != 'latitude' and key != 'longitude':
                clusterlabel.append(key)

    elemcounts = Counter(clusterlabel)
    mostcommon = elemcounts.most_common(1)
    return mostcommon[0][0]

c = labelit(cluster0, data)
print("The cluster's label defined by the green dots is "+c)
d = labelit(cluster1, data)
print("The cluster's label defined by the blue dots is "+d)
e = labelit(cluster2, data)
print("The cluster's label defined by the red dots is "+e)
f = labelit(cluster3, data)
print("The cluster's label defined by the yellow dots is "+f)
g = labelit(cluster4, data)
print("The cluster's label defined by the cyan dots is "+g)
h = labelit(cluster5, data)
print("The cluster's label defined by the purple dots is "+h)
p = labelit(cluster6, data)
print("The cluster's label defined by the black dots is "+p)
o = labelit(cluster7, data)
print("The cluster's label defined by the white dots is "+o)


colors = ["g.", "b.", "r.", "y.", "c.", "m.", "k.", "w."]

for i in range(len(vector_arr)):
    plt.plot(vector_arr[i, 161], vector_arr[i, 162], colors[labels[i]], markersize = 10)
# Out:
# The cluster's label defined by the green dots is Mexican
# The cluster's label defined by the blue dots is Pizza
# The cluster's label defined by the red dots is American (Traditional)
# The cluster's label defined by the yellow dots is Mexican
# The cluster's label defined by the cyan dots is Nightlife
# The cluster's label defined by the purple dots is Fast Food
# The cluster's label defined by the black dots is Steakhouses
# The cluster's label defined by the white dots is Japanese

# %%
error = np.zeros(11)
error[0] = 0;
for k in range(1,11):
    kmeans = KMeans(init='k-means++', n_clusters=k, n_init=10)
    kmeans.fit_predict(vector_arr)
    error[k] = kmeans.inertia_

plt.plot(range(1,len(error)),error[1:])
plt.xlabel('Number of clusters')
plt.ylabel('Error')

# %%
#Hierarchical
hierarch_sp = linkage(vector_arr, method = 'complete', metric = 'euclidean')
coph_dists = cophenet(hierarch_sp, pdist(vector_arr))
print (hierarch_sp[:60])
'''
restindex = -1
cluster0 = []
cluster1 = []
cluster2 = []
cluster3 = []
cluster4 = []
cluster5 = []
cluster6 = []
cluster7 = []
cluster8 = []
for i in hierarch_sp:
    restindex = restindex + 1
    if i == 0:
        cluster0.append(restindex)
    if i == 1:
        cluster1.append(restindex)
    if i == 2:
        cluster2.append(restindex)
    if i == 3:
        cluster3.append(restindex)
    if i == 4:
        cluster4.append(restindex)
    if i == 5:
        cluster5.append(restindex)
    if i == 6:
        cluster6.append(restindex)
    if i == 7:
        cluster7.append(restindex)
    if i == 8:
        cluster8.append(restindex)
        
c = labelit(cluster0, data)
print("The cluster's label defined by the leftmost green subtree is "+c)
d = labelit(cluster1, data)
print("The cluster's label defined by the leftmost red subtree is "+d)
e = labelit(cluster2, data)
print("The cluster's label defined by the leftmost turquoise subtree is "+e)
f = labelit(cluster3, data)
print("The cluster's label defined by the purple subtree is "+f)
g = labelit(cluster4, data)
print("The cluster's label defined by the yellow subtree is "+g)
h = labelit(cluster5, data)
print("The cluster's label defined by the black subtree is "+h)
p = labelit(cluster6, data)
print("The cluster's label defined by the second green subtree is "+p)
o = labelit(cluster7, data)
print("The cluster's label defined by the second red subtree is "+o)
q = labelit(cluster8, data)
print("The cluster's label defined by the second turquoise subtree is "+q)
'''
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('restaurant index')
plt.ylabel('euclidean distance')

dendrogram(hierarch_sp, leaf_rotation=90., leaf_font_size=8.,)
plt.show()
# Out:
# [[  4.00000000e+00   4.40400000e+03   0.00000000e+00   2.00000000e+00]
#  [  8.30000000e+01   1.18000000e+02   0.00000000e+00   2.00000000e+00]
#  [  1.13000000e+02   1.03400000e+03   0.00000000e+00   2.00000000e+00]
#  [  1.17000000e+02   1.67400000e+03   0.00000000e+00   2.00000000e+00]
#  [  1.42000000e+02   2.74800000e+03   0.00000000e+00   2.00000000e+00]
#  [  1.91000000e+02   4.05400000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.55000000e+02   4.38300000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.88000000e+02   2.89000000e+02   0.00000000e+00   2.00000000e+00]
#  [  3.77000000e+02   4.02900000e+03   0.00000000e+00   2.00000000e+00]
#  [  4.15000000e+02   2.11800000e+03   0.00000000e+00   2.00000000e+00]
#  [  5.80000000e+02   2.46600000e+03   0.00000000e+00   2.00000000e+00]
#  [  7.10000000e+02   4.07700000e+03   0.00000000e+00   2.00000000e+00]
#  [  8.52000000e+02   4.33900000e+03   0.00000000e+00   2.00000000e+00]
#  [  9.14000000e+02   4.12400000e+03   0.00000000e+00   2.00000000e+00]
#  [  9.47000000e+02   1.51900000e+03   0.00000000e+00   2.00000000e+00]
#  [  1.09800000e+03   2.76200000e+03   0.00000000e+00   2.00000000e+00]
#  [  1.37400000e+03   2.13900000e+03   0.00000000e+00   2.00000000e+00]
#  [  1.53400000e+03   2.42100000e+03   0.00000000e+00   2.00000000e+00]
#  [  1.67000000e+03   3.56200000e+03   0.00000000e+00   2.00000000e+00]
#  [  1.70400000e+03   2.02500000e+03   0.00000000e+00   2.00000000e+00]
#  [  1.76300000e+03   2.72000000e+03   0.00000000e+00   2.00000000e+00]
#  [  1.88000000e+03   2.02700000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.02400000e+03   3.88900000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.04100000e+03   3.19600000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.08400000e+03   2.72500000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.08800000e+03   3.34600000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.10500000e+03   2.42700000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.14400000e+03   3.51800000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.25400000e+03   2.84800000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.37000000e+03   3.44600000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.42400000e+03   3.01700000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.49700000e+03   4.14200000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.77200000e+03   3.19400000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.79000000e+03   2.79200000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.89300000e+03   4.51600000e+03   0.00000000e+00   3.00000000e+00]
#  [  2.79800000e+03   2.94600000e+03   0.00000000e+00   2.00000000e+00]
#  [  2.81500000e+03   2.84500000e+03   0.00000000e+00   2.00000000e+00]
#  [  3.35000000e+03   4.51900000e+03   0.00000000e+00   3.00000000e+00]
#  [  3.20800000e+03   3.23700000e+03   0.00000000e+00   2.00000000e+00]
#  [  3.29100000e+03   3.72300000e+03   0.00000000e+00   2.00000000e+00]
#  [  3.35700000e+03   3.45700000e+03   0.00000000e+00   2.00000000e+00]
#  [  3.36900000e+03   3.70400000e+03   0.00000000e+00   2.00000000e+00]
#  [  3.54100000e+03   4.19600000e+03   0.00000000e+00   2.00000000e+00]
#  [  3.94500000e+03   4.52200000e+03   0.00000000e+00   3.00000000e+00]
#  [  4.19200000e+03   4.52600000e+03   0.00000000e+00   4.00000000e+00]
#  [  3.97800000e+03   4.11600000e+03   0.00000000e+00   2.00000000e+00]
#  [  4.55000000e+02   3.30400000e+03   2.81256416e-05   2.00000000e+00]
#  [  1.73400000e+03   3.20200000e+03   3.99785837e-05   2.00000000e+00]
#  [  3.72000000e+03   4.37000000e+03   5.91383980e-05   2.00000000e+00]
#  [  1.82000000e+02   3.95600000e+03   6.32787689e-05   2.00000000e+00]
#  [  3.37800000e+03   4.25300000e+03   7.72710458e-05   2.00000000e+00]
#  [  2.83900000e+03   2.96500000e+03   8.16577153e-05   2.00000000e+00]
#  [  8.39000000e+02   1.71700000e+03   8.31372961e-05   2.00000000e+00]
#  [  6.61000000e+02   3.55900000e+03   9.04170891e-05   2.00000000e+00]
#  [  1.98200000e+03   3.77000000e+03   1.06194586e-04   2.00000000e+00]
#  [  3.18500000e+03   3.96600000e+03   1.06996873e-04   2.00000000e+00]
#  [  3.23000000e+02   3.48900000e+03   1.26280046e-04   2.00000000e+00]
#  [  1.60200000e+03   4.46000000e+03   1.34478697e-04   2.00000000e+00]
#  [  1.66900000e+03   2.87500000e+03   1.49614739e-04   2.00000000e+00]
#  [  3.00900000e+03   3.27900000e+03   1.71122707e-04   2.00000000e+00]]

# %%
#GMM
gmm.fit(vector_arr)
y_pred =gmm.predict(vector_arr)

restindex = -1
cluster0 = []
cluster1 = []
cluster2 = []
cluster3 = []
cluster4 = []
cluster5 = []
cluster6 = []
cluster7 = []
for i in y_pred:
    restindex = restindex + 1
    if i == 0:
        cluster0.append(restindex)
    if i == 1:
        cluster1.append(restindex)
    if i == 2:
        cluster2.append(restindex)
    if i == 3:
        cluster3.append(restindex)
    if i == 4:
        cluster4.append(restindex)
    if i == 5:
        cluster5.append(restindex)
    if i == 6:
        cluster6.append(restindex)
    if i == 7:
        cluster7.append(restindex)
        
c = labelit(cluster0, data)
print("The cluster's label defined by the green dots is "+c)
d = labelit(cluster1, data)
print("The cluster's label defined by the blue dots is "+d)
e = labelit(cluster2, data)
print("The cluster's label defined by the red dots is "+e)
f = labelit(cluster3, data)
print("The cluster's label defined by the yellow dots is "+f)
g = labelit(cluster4, data)
print("The cluster's label defined by the cyan dots is "+g)
h = labelit(cluster5, data)
print("The cluster's label defined by the purple dots is "+h)
p = labelit(cluster6, data)
print("The cluster's label defined by the black dots is "+p)
o = labelit(cluster7, data)
print("The cluster's label defined by the white dots is "+o)


colors = ["g.", "b.", "r.", "y.", "c.", "m.", "k.", "w."]

for i in range(len(vector_arr)):
    plt.plot(vector_arr[i, 161], vector_arr[i, 162], colors[y_pred[i]], markersize = 10)
# Out:
# 4483
# The cluster's label defined by the green dots is Chinese
# The cluster's label defined by the blue dots is Mediterranean
# The cluster's label defined by the red dots is Food
# The cluster's label defined by the yellow dots is Breakfast & Brunch
# The cluster's label defined by the cyan dots is Nightlife
# The cluster's label defined by the purple dots is Steakhouses
# The cluster's label defined by the black dots is Fast Food
# The cluster's label defined by the white dots is Pizza

# %% [markdown]
# Now let's detect outliers. These are the ones who are the farthest from the centroids of their clusters. Track them down and describe any interesting observations that you can make. **(10 pts)**

# %% [markdown]
# Give a short (detailed) analysis comparing the 3 techniques. **(10 pts)**

# %% [markdown]
# -----------------

# %%
# Code for setting the style of the notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("../theme/custom.css", "r").read()
    return HTML(styles)
css_styling()
